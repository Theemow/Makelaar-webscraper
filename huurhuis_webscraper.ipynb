# %% [markdown]
# # Huurhuis webscraper
#
# Dit is een coding project dat automatisch de verschillende websites van makelaars scraped en doormailt naar mij.

# %% [markdown]
# ## PLAN:
#
# ### Database (Postgress):
#
# BrokerAgencies
# CREATE TABLE BrokerAgencies (
#     MakelaardijID SERIAL PRIMARY KEY,
#     Naam TEXT NOT NULL,
#     Link TEXT NOT NULL
#     BrokerName TEXT NOT NULL,
#     Hyperlink TEXT NOT NULL,
#     BrokerId SERIAL PRIMARY KEY
# );
#
# Property
# CREATE TABLE Property (
#     MakelaardijID INT REFERENCES Makelaardij(MakelaardijID),
#     Adres TEXT NOT NULL,
#     Link TEXT NOT NULL,
#     ToegevoegdOp DATE NOT NULL,
#     NaamDorpStad TEXT NOT NULL,
#     Huurprijs TEXT NOT NULL,
#     Oppervlakte TEXT NOT NULL,
#     BrokerId INT REFERENCES BrokerAgencies(BrokerId),
#     Hyperlink TEXT NOT NULL,
#     Price TEXT NOT NULL,
#     Size TEXT NOT NULL
# );
#
# #### CRUD:
# Create:
# CreateNewBrokerAgency
# CreateNewRentalProperty
#
# Read:
# GetBrokerAgency
# GetPropertiesForBroker
# GetAllProperties
# GetAllPropertiesForLocation
#
# Update:
# UpdatePropertie
# UpdateBrokerAgency
#
# Delete:
# RemoveProperty
# RemoveBrokerAgency
#
#
#
# ### Webscraper (python):
#
# Moet kunnen ophalen:
# - Link naar appartement
# - Adress
# - Huurprijs
# - Oppervlakte
#
#
#
# ### Communicatielaag (python):
#
# communiceren tussen webscraper en db.
# uit locatie naam van dorp halen.
# logica voor aanmaken van items in de db.
# Controlleren op nieuwe appartementen.
# Opstellen mail met nieuwe appartementen en wat basis data.
#
#
#
# ### Mail service (python):
#
# Moet een mail kunnen versturen naar mijn of een andere mail.
#
#
#
# Moet kunnen draaien in een container die een of meerdere malen per dag kan worden afgevuurd (Liefst rond 12 uur smiddags en 6 uur savonds).
# kan blijkbaar via crontab op linux

# %% [markdown]
# ## Imports:

# %%
import psycopg2
from psycopg2 import sql
from datetime import date
from dataclasses import dataclass
from typing import List, Optional
import requests
from bs4 import BeautifulSoup
from abc import ABC, abstractmethod
import re
from urllib.parse import urljoin
from typing import Dict, List, Optional, Union, Any
import logging
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from queue import Queue
import logging
from datetime import datetime

# Import configuration
from config import DATABASE, EMAIL

# Import mail service
from mail_service import MailService

# Import data access
from data_access import DataAccess, BrokerAgency, Property

# Import logging service
from log_service import LogService, get_logger
# Out:
# 2025-05-13 20:38:21,712 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Started =====
# 2025-05-13 20:38:21,714 - [MainThread] - root - INFO - Start time: 2025-05-13 20:38:21
# 2025-05-13 20:38:21,714 - [MainThread] - root - INFO - Start time: 2025-05-13 20:38:21

# %% [markdown]
# ## Main:

# %%
# Importeer de connector
from connector import Connector


# Uitbreiden van connector met factory functies voor onze datamodellen
class Huurhuisconnector(Connector):
    def _create_broker_agency(self, id, naam, link):
        """Factory functie die een BrokerAgency object aanmaakt met de klasse uit data_access.py."""
        return BrokerAgency(id=id, naam=naam, link=link)

    def _create_property(
        self,
        makelaardij_id,
        adres,
        link,
        toegevoegd_op,
        naam_dorp_stad,
        huurprijs,
        oppervlakte,
    ):
        """Factory functie die een Property object aanmaakt met de klasse uit data_access.py."""
        return Property(
            makelaardij_id=makelaardij_id,
            adres=adres,
            link=link,
            toegevoegd_op=toegevoegd_op,
            naam_dorp_stad=naam_dorp_stad,
            huurprijs=huurprijs,
            oppervlakte=oppervlakte,
        )


def run_scraper_proces():
    """Voer het volledige scraper proces uit."""
    # Initialize logging service
    log_service = LogService()
    logger = get_logger("HuurhuisWebscraper")

    # Log application start
    log_service.log_app_start()

    # Initialiseer de database-verbinding
    db = DataAccess()

    # Initialiseer de connector met onze aangepaste versie
    communicatie = Huurhuisconnector(db)

    # Lijst met te verwerken makelaars en hun scraper-type
    makelaars = [
        {
            "naam": "Van Roomen Van de Bunt NVM Makelaars",
            "type": "vdbunt",
            "url": "https://www.vdbunt.nl/aanbod/woningaanbod/huur/",
        },
        {
            "naam": "Pararius",
            "type": "pararius",
            "url": "https://www.pararius.nl/huurwoningen/leusden/",
        },
        {
            "naam": "Zonnenberg Makelaardij",
            "type": "zonnenberg",
            "url": "https://zonnenbergmakelaardij.nl/woningaanbod/huur/",
        },
        {
            "naam": "Ditters Makelaars",
            "type": "ditters",
            "url": "https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur",
        },
        {
            "naam": "InterHouse Utrecht",
            "type": "interhouse-utrecht",
            "url": "https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list",
        },
        {
            "naam": "InterHouse Amersfoort",
            "type": "interhouse-amersfoort",
            "url": "https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list",
        },
        {
            "naam": "VastgoedNederland Veenendaal",
            "type": "vastgoednederland",
            "url": "https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000",
        },
        {
            "naam": "VBT Verhuurmakelaars",
            "type": "vbt",
            "url": "https://vbtverhuurmakelaars.nl/woningen",
        },
    ]

    # Set main thread name for better logging
    threading.current_thread().name = "MainThread"
    logger.info("Starting multithreaded scraper process")

    # Process brokers in parallel and gather results
    # Use max_workers based on number of brokers - for 4 brokers, use 4 threads
    max_workers = len(makelaars)
    logger.info(
        f"Processing {len(makelaars)} brokers with {max_workers} worker threads"
    )

    alle_nieuwe_properties, alle_verwijderde_properties = (
        communicatie.parallel_process_brokers(makelaars, max_workers=max_workers)
    )

    # After all scrapers have completed, synchronously apply database updates
    logger.info("All scrapers finished. Applying database updates synchronously...")
    communicatie.apply_database_updates(
        alle_nieuwe_properties, alle_verwijderde_properties
    )

    # Toon resultaten
    logger.info(f"Total new properties: {len(alle_nieuwe_properties)}")
    logger.info(f"Total removed properties: {len(alle_verwijderde_properties)}")

    # Verstuur mail met nieuwe woningen
    if alle_nieuwe_properties:
        logger.info(f"Sending email with {len(alle_nieuwe_properties)} new properties")

        # Initialiseer de mail service met de configuratie uit config.py
        mail_service = MailService()

        # Verstuur de mail met nieuwe woningen
        mail_success = mail_service.send_new_properties_email(
            None, alle_nieuwe_properties
        )

        if mail_success:
            logger.info(
                f"E-mail with {len(alle_nieuwe_properties)} new properties successfully sent to {len(EMAIL['recipients'])} recipient(s)"
            )
        else:
            logger.error("There was a problem sending the email.")

    # Log application end
    log_service.log_app_end(
        len(alle_nieuwe_properties), len(alle_verwijderde_properties)
    )


run_scraper_proces()
# Out:
# 2025-05-13 20:38:21,831 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Started =====
# 2025-05-13 20:38:21,831 - [MainThread] - root - INFO - Start time: 2025-05-13 20:38:21
# 2025-05-13 20:38:21,832 - [MainThread] - HuurhuisWebscraper - INFO - Starting multithreaded scraper process
# 2025-05-13 20:38:21,832 - [MainThread] - HuurhuisWebscraper - INFO - Processing 8 brokers with 8 worker threads
# 2025-05-13 20:38:21,833 - [MainThread] - connector - INFO - Starting parallel processing of 8 brokers with max_workers=8
# 2025-05-13 20:38:21,834 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Verwerken van makelaar: Van Roomen Van de Bunt NVM Makelaars op thread Thread-Van Roomen Van de Bunt NVM Makelaars
# 2025-05-13 20:38:21,836 - [Thread-Pararius] - connector - INFO - Verwerken van makelaar: Pararius op thread Thread-Pararius
# 2025-05-13 20:38:21,831 - [MainThread] - root - INFO - Start time: 2025-05-13 20:38:21
# 2025-05-13 20:38:21,832 - [MainThread] - HuurhuisWebscraper - INFO - Starting multithreaded scraper process
# 2025-05-13 20:38:21,832 - [MainThread] - HuurhuisWebscraper - INFO - Processing 8 brokers with 8 worker threads
# 2025-05-13 20:38:21,833 - [MainThread] - connector - INFO - Starting parallel processing of 8 brokers with max_workers=8
# 2025-05-13 20:38:21,834 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Verwerken van makelaar: Van Roomen Van de Bunt NVM Makelaars op thread Thread-Van Roomen Van de Bunt NVM Makelaars
# 2025-05-13 20:38:21,836 - [Thread-Pararius] - connector - INFO - Verwerken van makelaar: Pararius op thread Thread-Pararius
# 2025-05-13 20:38:21,837 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Verwerken van makelaar: Zonnenberg Makelaardij op thread Thread-Zonnenberg Makelaardij
# 2025-05-13 20:38:21,838 - [Thread-Ditters Makelaars] - connector - INFO - Verwerken van makelaar: Ditters Makelaars op thread Thread-Ditters Makelaars
# 2025-05-13 20:38:21,839 - [Thread-InterHouse Utrecht] - connector - INFO - Verwerken van makelaar: InterHouse Utrecht op thread Thread-InterHouse Utrecht
# 2025-05-13 20:38:21,839 - [Thread-InterHouse Amersfoort] - connector - INFO - Verwerken van makelaar: InterHouse Amersfoort op thread Thread-InterHouse Amersfoort
# 2025-05-13 20:38:21,839 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Verwerken van makelaar: VastgoedNederland Veenendaal op thread Thread-VastgoedNederland Veenendaal
# 2025-05-13 20:38:21,837 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Verwerken van makelaar: Zonnenberg Makelaardij op thread Thread-Zonnenberg Makelaardij
# 2025-05-13 20:38:21,838 - [Thread-Ditters Makelaars] - connector - INFO - Verwerken van makelaar: Ditters Makelaars op thread Thread-Ditters Makelaars
# 2025-05-13 20:38:21,839 - [Thread-InterHouse Utrecht] - connector - INFO - Verwerken van makelaar: InterHouse Utrecht op thread Thread-InterHouse Utrecht
# 2025-05-13 20:38:21,839 - [Thread-InterHouse Amersfoort] - connector - INFO - Verwerken van makelaar: InterHouse Amersfoort op thread Thread-InterHouse Amersfoort
# 2025-05-13 20:38:21,839 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Verwerken van makelaar: VastgoedNederland Veenendaal op thread Thread-VastgoedNederland Veenendaal
# 2025-05-13 20:38:21,841 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Verwerken van makelaar: VBT Verhuurmakelaars op thread Thread-VBT Verhuurmakelaars
# 2025-05-13 20:38:21,841 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Verwerken van makelaar: VBT Verhuurmakelaars op thread Thread-VBT Verhuurmakelaars
# 2025-05-13 20:38:21,923 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,924 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/
# 2025-05-13 20:38:21,930 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,923 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,924 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/
# 2025-05-13 20:38:21,930 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,946 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,948 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,948 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur
# 2025-05-13 20:38:21,948 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 20:38:21,949 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Initialized VastgoedNederland scraper for location: veenendaal
# 2025-05-13 20:38:21,954 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,954 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Fetching VastgoedNederland listings page 1: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000
# 2025-05-13 20:38:21,955 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Retrieving page: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000
# 2025-05-13 20:38:21,956 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Initialized VBT scraper with base URL: https://vbtverhuurmakelaars.nl/woningen
# 2025-05-13 20:38:21,946 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,948 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,948 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur
# 2025-05-13 20:38:21,948 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 20:38:21,949 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Initialized VastgoedNederland scraper for location: veenendaal
# 2025-05-13 20:38:21,954 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,954 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Fetching VastgoedNederland listings page 1: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000
# 2025-05-13 20:38:21,955 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Retrieving page: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000
# 2025-05-13 20:38:21,956 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Initialized VBT scraper with base URL: https://vbtverhuurmakelaars.nl/woningen
# 2025-05-13 20:38:21,959 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,959 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,960 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Scraping VBT page: https://vbtverhuurmakelaars.nl/woningen
# 2025-05-13 20:38:21,961 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 20:38:21,959 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,959 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,960 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Scraping VBT page: https://vbtverhuurmakelaars.nl/woningen
# 2025-05-13 20:38:21,961 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 20:38:21,984 - [Thread-InterHouse Amersfoort] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 20:38:21,985 - [Thread-InterHouse Utrecht] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 20:38:21,994 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - VdBunt scraper only processes first page since pagination is not supported
# 2025-05-13 20:38:21,995 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,996 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Retrieving page: https://www.vdbunt.nl/aanbod/woningaanbod/huur/
# 2025-05-13 20:38:21,984 - [Thread-InterHouse Amersfoort] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 20:38:21,985 - [Thread-InterHouse Utrecht] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 20:38:21,994 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - VdBunt scraper only processes first page since pagination is not supported
# 2025-05-13 20:38:21,995 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Processing page 1
# 2025-05-13 20:38:21,996 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Retrieving page: https://www.vdbunt.nl/aanbod/woningaanbod/huur/
# 2025-05-13 20:38:22,140 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 3 properties on Ditters website (page 1)
# 2025-05-13 20:38:22,146 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Page: 1 | Found new: 3 | Duplicates: 0
# 2025-05-13 20:38:22,147 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,147 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur&page=2
# 2025-05-13 20:38:22,140 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 3 properties on Ditters website (page 1)
# 2025-05-13 20:38:22,146 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Page: 1 | Found new: 3 | Duplicates: 0
# 2025-05-13 20:38:22,147 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,147 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur&page=2
# 2025-05-13 20:38:22,272 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 0 properties on Ditters website (page 2)
# 2025-05-13 20:38:22,272 - [Thread-Ditters Makelaars] - DittersScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:22,274 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Total properties found: 3
# 2025-05-13 20:38:22,275 - [Thread-Ditters Makelaars] - connector - INFO - Makelaar: Ditters Makelaars| Gevonden properties: 3
# 2025-05-13 20:38:22,272 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 0 properties on Ditters website (page 2)
# 2025-05-13 20:38:22,272 - [Thread-Ditters Makelaars] - DittersScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:22,274 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Total properties found: 3
# 2025-05-13 20:38:22,275 - [Thread-Ditters Makelaars] - connector - INFO - Makelaar: Ditters Makelaars| Gevonden properties: 3
# 2025-05-13 20:38:22,332 - [Thread-Ditters Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:22,332 - [Thread-Ditters Makelaars] - connector - INFO - Bestaande properties: 3
# 2025-05-13 20:38:22,334 - [Thread-Ditters Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:22,334 - [Thread-Ditters Makelaars] - root - INFO - Broker: Ditters Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:22,332 - [Thread-Ditters Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:22,332 - [Thread-Ditters Makelaars] - connector - INFO - Bestaande properties: 3
# 2025-05-13 20:38:22,334 - [Thread-Ditters Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:22,334 - [Thread-Ditters Makelaars] - root - INFO - Broker: Ditters Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:22,532 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Found 6 properties on VastgoedNederland page 1
# 2025-05-13 20:38:22,532 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Found 6 properties on VastgoedNederland page 1
# 2025-05-13 20:38:22,580 - [Thread-Pararius] - ParariusScraper - INFO - Page: 1 | Found new: 30 | Duplicates: 0
# 2025-05-13 20:38:22,584 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Page: 1 | Found new: 5 | Duplicates: 1
# 2025-05-13 20:38:22,585 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,580 - [Thread-Pararius] - ParariusScraper - INFO - Page: 1 | Found new: 30 | Duplicates: 0
# 2025-05-13 20:38:22,584 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Page: 1 | Found new: 5 | Duplicates: 1
# 2025-05-13 20:38:22,585 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,586 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,586 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Processing page 2
# 2025-05-13 20:38:22,587 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/page-2
# 2025-05-13 20:38:22,629 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - Found 2 properties on VdBunt website
# 2025-05-13 20:38:22,629 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Fetching VastgoedNederland listings page 2: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000&p=2
# 2025-05-13 20:38:22,636 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 20:38:22,637 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Retrieving page: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000&p=2
# 2025-05-13 20:38:22,637 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Total properties found: 2
# 2025-05-13 20:38:22,638 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Makelaar: Van Roomen Van de Bunt NVM Makelaars| Gevonden properties: 2
# 2025-05-13 20:38:22,587 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/page-2
# 2025-05-13 20:38:22,629 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - Found 2 properties on VdBunt website
# 2025-05-13 20:38:22,629 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Fetching VastgoedNederland listings page 2: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000&p=2
# 2025-05-13 20:38:22,636 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 20:38:22,637 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Retrieving page: https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000&p=2
# 2025-05-13 20:38:22,637 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Total properties found: 2
# 2025-05-13 20:38:22,638 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Makelaar: Van Roomen Van de Bunt NVM Makelaars| Gevonden properties: 2
# 2025-05-13 20:38:22,688 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:22,689 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 20:38:22,689 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:22,690 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - root - INFO - Broker: Van Roomen Van de Bunt NVM Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:22,688 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:22,689 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 20:38:22,689 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:22,690 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - root - INFO - Broker: Van Roomen Van de Bunt NVM Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:23,006 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,009 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,006 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,009 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,039 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,040 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,039 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,040 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 20:38:23,087 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 20:38:23,098 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 2
# 2025-05-13 20:38:23,103 - [Thread-InterHouse Amersfoort] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 20:38:23,103 - [Thread-InterHouse Utrecht] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 20:38:23,105 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Found 0 properties on VastgoedNederland page 2
# 2025-05-13 20:38:23,112 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:23,113 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Total properties found: 5
# 2025-05-13 20:38:23,114 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Makelaar: VastgoedNederland Veenendaal| Gevonden properties: 5
# 2025-05-13 20:38:23,087 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 20:38:23,098 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 2
# 2025-05-13 20:38:23,103 - [Thread-InterHouse Amersfoort] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 20:38:23,103 - [Thread-InterHouse Utrecht] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 20:38:23,105 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Found 0 properties on VastgoedNederland page 2
# 2025-05-13 20:38:23,112 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:23,113 - [Thread-VastgoedNederland Veenendaal] - VastgoedNederlandScraper - INFO - Total properties found: 5
# 2025-05-13 20:38:23,114 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Makelaar: VastgoedNederland Veenendaal| Gevonden properties: 5
# 2025-05-13 20:38:23,195 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:23,195 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:23,265 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Bestaande properties: 5
# 2025-05-13 20:38:23,311 - [Thread-Pararius] - ParariusScraper - INFO - All 30 listings on page 2 are duplicates. Stopping pagination.
# 2025-05-13 20:38:23,312 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:23,312 - [Thread-Pararius] - ParariusScraper - INFO - Total properties found: 30
# 2025-05-13 20:38:23,314 - [Thread-VastgoedNederland Veenendaal] - root - INFO - Broker: VastgoedNederland Veenendaal | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:23,315 - [Thread-Pararius] - connector - INFO - Makelaar: Pararius| Gevonden properties: 30
# 2025-05-13 20:38:23,265 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Bestaande properties: 5
# 2025-05-13 20:38:23,311 - [Thread-Pararius] - ParariusScraper - INFO - All 30 listings on page 2 are duplicates. Stopping pagination.
# 2025-05-13 20:38:23,312 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:23,312 - [Thread-Pararius] - ParariusScraper - INFO - Total properties found: 30
# 2025-05-13 20:38:23,314 - [Thread-VastgoedNederland Veenendaal] - root - INFO - Broker: VastgoedNederland Veenendaal | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:23,315 - [Thread-Pararius] - connector - INFO - Makelaar: Pararius| Gevonden properties: 30
# 2025-05-13 20:38:23,365 - [Thread-Pararius] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:23,365 - [Thread-Pararius] - connector - INFO - Bestaande properties: 30
# 2025-05-13 20:38:23,366 - [Thread-Pararius] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:23,367 - [Thread-Pararius] - root - INFO - Broker: Pararius | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:23,365 - [Thread-Pararius] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:23,365 - [Thread-Pararius] - connector - INFO - Bestaande properties: 30
# 2025-05-13 20:38:23,366 - [Thread-Pararius] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:23,367 - [Thread-Pararius] - root - INFO - Broker: Pararius | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:24,085 - [Thread-Zonnenberg Makelaardij] - WebScraper - ERROR - Failed to get content from https://zonnenbergmakelaardij.nl/woningaanbod/huur/page/2/, status code: 404
# 2025-05-13 20:38:24,086 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:24,086 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Total properties found: 2
# 2025-05-13 20:38:24,087 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Makelaar: Zonnenberg Makelaardij| Gevonden properties: 2
# 2025-05-13 20:38:24,085 - [Thread-Zonnenberg Makelaardij] - WebScraper - ERROR - Failed to get content from https://zonnenbergmakelaardij.nl/woningaanbod/huur/page/2/, status code: 404
# 2025-05-13 20:38:24,086 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:24,086 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Total properties found: 2
# 2025-05-13 20:38:24,087 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Makelaar: Zonnenberg Makelaardij| Gevonden properties: 2
# 2025-05-13 20:38:24,138 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 20:38:24,138 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 20:38:24,138 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 20:38:24,138 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 20:38:24,254 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:24,255 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Bestaande properties: 2
# 2025-05-13 20:38:24,256 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:24,256 - [Thread-Zonnenberg Makelaardij] - root - INFO - Broker: Zonnenberg Makelaardij | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:24,254 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:24,255 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Bestaande properties: 2
# 2025-05-13 20:38:24,256 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:24,256 - [Thread-Zonnenberg Makelaardij] - root - INFO - Broker: Zonnenberg Makelaardij | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:25,365 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 9 properties on InterHouse website for Utrecht (page 1)
# 2025-05-13 20:38:25,374 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Page: 1 | Found new: 9 | Duplicates: 0
# 2025-05-13 20:38:25,375 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 20:38:25,376 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 20:38:25,365 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 9 properties on InterHouse website for Utrecht (page 1)
# 2025-05-13 20:38:25,374 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Page: 1 | Found new: 9 | Duplicates: 0
# 2025-05-13 20:38:25,375 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 20:38:25,376 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 20:38:25,486 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 7 properties on InterHouse website for Amersfoort (page 1)
# 2025-05-13 20:38:25,492 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 20:38:25,493 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 20:38:25,494 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 20:38:25,486 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 7 properties on InterHouse website for Amersfoort (page 1)
# 2025-05-13 20:38:25,492 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 20:38:25,493 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 20:38:25,494 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 20:38:26,244 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Utrecht (page 2)
# 2025-05-13 20:38:26,245 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:26,245 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Total properties found: 9
# 2025-05-13 20:38:26,244 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Utrecht (page 2)
# 2025-05-13 20:38:26,245 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:26,245 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Total properties found: 9
# 2025-05-13 20:38:26,365 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Amersfoort (page 2)
# 2025-05-13 20:38:26,367 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:26,368 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Total properties found: 7
# 2025-05-13 20:38:26,365 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Amersfoort (page 2)
# 2025-05-13 20:38:26,367 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:38:26,368 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Total properties found: 7
# 2025-05-13 20:38:28,343 - [Thread-InterHouse Utrecht] - connector - INFO - Makelaar: InterHouse Utrecht| Gevonden properties: 9
# 2025-05-13 20:38:28,343 - [Thread-InterHouse Utrecht] - connector - INFO - Makelaar: InterHouse Utrecht| Gevonden properties: 9
# 2025-05-13 20:38:28,382 - [Thread-InterHouse Utrecht] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:28,383 - [Thread-InterHouse Utrecht] - connector - INFO - Bestaande properties: 9
# 2025-05-13 20:38:28,384 - [Thread-InterHouse Utrecht] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:28,384 - [Thread-InterHouse Utrecht] - root - INFO - Broker: InterHouse Utrecht | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:28,382 - [Thread-InterHouse Utrecht] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:28,383 - [Thread-InterHouse Utrecht] - connector - INFO - Bestaande properties: 9
# 2025-05-13 20:38:28,384 - [Thread-InterHouse Utrecht] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:28,384 - [Thread-InterHouse Utrecht] - root - INFO - Broker: InterHouse Utrecht | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:28,442 - [Thread-InterHouse Amersfoort] - connector - INFO - Makelaar: InterHouse Amersfoort| Gevonden properties: 7
# 2025-05-13 20:38:28,442 - [Thread-InterHouse Amersfoort] - connector - INFO - Makelaar: InterHouse Amersfoort| Gevonden properties: 7
# 2025-05-13 20:38:28,483 - [Thread-InterHouse Amersfoort] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:28,484 - [Thread-InterHouse Amersfoort] - connector - INFO - Bestaande properties: 7
# 2025-05-13 20:38:28,484 - [Thread-InterHouse Amersfoort] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:28,485 - [Thread-InterHouse Amersfoort] - root - INFO - Broker: InterHouse Amersfoort | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:28,483 - [Thread-InterHouse Amersfoort] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 20:38:28,484 - [Thread-InterHouse Amersfoort] - connector - INFO - Bestaande properties: 7
# 2025-05-13 20:38:28,484 - [Thread-InterHouse Amersfoort] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 20:38:28,485 - [Thread-InterHouse Amersfoort] - root - INFO - Broker: InterHouse Amersfoort | New properties: 0 | Removed properties: 0
# 2025-05-13 20:38:43,165 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Found 7 properties on page 1
# 2025-05-13 20:38:43,168 - [Thread-VBT Verhuurmakelaars] - VBTScraper - WARNING - Missing oppervlakte for property
# 2025-05-13 20:38:43,169 - [Thread-VBT Verhuurmakelaars] - VBTScraper - WARNING - Missing oppervlakte for property
# 2025-05-13 20:38:43,170 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 20:38:43,171 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Processing page 2
# 2025-05-13 20:38:43,172 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Scraping VBT page: https://vbtverhuurmakelaars.nl/woningen/2
# 2025-05-13 20:38:43,165 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Found 7 properties on page 1
# 2025-05-13 20:38:43,168 - [Thread-VBT Verhuurmakelaars] - VBTScraper - WARNING - Missing oppervlakte for property
# 2025-05-13 20:38:43,169 - [Thread-VBT Verhuurmakelaars] - VBTScraper - WARNING - Missing oppervlakte for property
# 2025-05-13 20:38:43,170 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 20:38:43,171 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Processing page 2
# 2025-05-13 20:38:43,172 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Scraping VBT page: https://vbtverhuurmakelaars.nl/woningen/2
# 2025-05-13 20:39:04,397 - [Thread-VBT Verhuurmakelaars] - VBTScraper - ERROR - Error scraping VBT page 2: 404 Client Error: Not Found for url: https://vbtverhuurmakelaars.nl/woningen/2
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Total properties found: 7
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Makelaar: VBT Verhuurmakelaars| Gevonden properties: 7
# 2025-05-13 20:39:04,397 - [Thread-VBT Verhuurmakelaars] - VBTScraper - ERROR - Error scraping VBT page 2: 404 Client Error: Not Found for url: https://vbtverhuurmakelaars.nl/woningen/2
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - VBTScraper - INFO - Total properties found: 7
# 2025-05-13 20:39:04,398 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Makelaar: VBT Verhuurmakelaars| Gevonden properties: 7
# 2025-05-13 20:39:04,440 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Nieuwe properties: 7
# 2025-05-13 20:39:04,440 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Bestaande properties: 0
# 2025-05-13 20:39:04,441 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Te verwijderen properties: 7
# 2025-05-13 20:39:04,441 - [Thread-VBT Verhuurmakelaars] - root - INFO - Broker: VBT Verhuurmakelaars | New properties: 7 | Removed properties: 7
# 2025-05-13 20:39:04,442 - [MainThread] - connector - INFO - Parallel processing completed - Found 7 new and 7 removed properties
# 2025-05-13 20:39:04,443 - [MainThread] - HuurhuisWebscraper - INFO - All scrapers finished. Applying database updates synchronously...
# 2025-05-13 20:39:04,443 - [MainThread] - connector - INFO - Applying database updates - 7 new, 7 removed
# 2025-05-13 20:39:04,440 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Nieuwe properties: 7
# 2025-05-13 20:39:04,440 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Bestaande properties: 0
# 2025-05-13 20:39:04,441 - [Thread-VBT Verhuurmakelaars] - connector - INFO - Te verwijderen properties: 7
# 2025-05-13 20:39:04,441 - [Thread-VBT Verhuurmakelaars] - root - INFO - Broker: VBT Verhuurmakelaars | New properties: 7 | Removed properties: 7
# 2025-05-13 20:39:04,442 - [MainThread] - connector - INFO - Parallel processing completed - Found 7 new and 7 removed properties
# 2025-05-13 20:39:04,443 - [MainThread] - HuurhuisWebscraper - INFO - All scrapers finished. Applying database updates synchronously...
# 2025-05-13 20:39:04,443 - [MainThread] - connector - INFO - Applying database updates - 7 new, 7 removed
# 2025-05-13 20:39:05,464 - [MainThread] - HuurhuisWebscraper - INFO - Total new properties: 7
# 2025-05-13 20:39:05,465 - [MainThread] - HuurhuisWebscraper - INFO - Total removed properties: 7
# 2025-05-13 20:39:05,465 - [MainThread] - HuurhuisWebscraper - INFO - Sending email with 7 new properties
# 2025-05-13 20:39:05,464 - [MainThread] - HuurhuisWebscraper - INFO - Total new properties: 7
# 2025-05-13 20:39:05,465 - [MainThread] - HuurhuisWebscraper - INFO - Total removed properties: 7
# 2025-05-13 20:39:05,465 - [MainThread] - HuurhuisWebscraper - INFO - Sending email with 7 new properties
# 2025-05-13 20:39:07,526 - [MainThread] - MailService - INFO - E-mail succesvol verzonden naar 1 ontvanger(s).
# 2025-05-13 20:39:07,527 - [MainThread] - HuurhuisWebscraper - INFO - E-mail with 7 new properties successfully sent to 1 recipient(s)
# 2025-05-13 20:39:07,527 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Completed =====
# 2025-05-13 20:39:07,528 - [MainThread] - root - INFO - End time: 2025-05-13 20:39:07
# 2025-05-13 20:39:07,529 - [MainThread] - root - INFO - New properties found: 7
# 2025-05-13 20:39:07,529 - [MainThread] - root - INFO - Properties removed: 7
# 2025-05-13 20:39:07,526 - [MainThread] - MailService - INFO - E-mail succesvol verzonden naar 1 ontvanger(s).
# 2025-05-13 20:39:07,527 - [MainThread] - HuurhuisWebscraper - INFO - E-mail with 7 new properties successfully sent to 1 recipient(s)
# 2025-05-13 20:39:07,527 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Completed =====
# 2025-05-13 20:39:07,528 - [MainThread] - root - INFO - End time: 2025-05-13 20:39:07
# 2025-05-13 20:39:07,529 - [MainThread] - root - INFO - New properties found: 7
# 2025-05-13 20:39:07,529 - [MainThread] - root - INFO - Properties removed: 7
