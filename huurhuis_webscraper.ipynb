# %% [markdown]
# # Huurhuis webscraper
#
# Dit is een coding project dat automatisch de verschillende websites van makelaars scraped en doormailt naar mij.

# %% [markdown]
# ## PLAN:
#
# ### Database (Postgress):
#
# BrokerAgencies
# CREATE TABLE BrokerAgencies (
#     MakelaardijID SERIAL PRIMARY KEY,
#     Naam TEXT NOT NULL,
#     Link TEXT NOT NULL
#     BrokerName TEXT NOT NULL,
#     Hyperlink TEXT NOT NULL,
#     BrokerId SERIAL PRIMARY KEY
# );
#
# Property
# CREATE TABLE Property (
#     MakelaardijID INT REFERENCES Makelaardij(MakelaardijID),
#     Adres TEXT NOT NULL,
#     Link TEXT NOT NULL,
#     ToegevoegdOp DATE NOT NULL,
#     NaamDorpStad TEXT NOT NULL,
#     Huurprijs TEXT NOT NULL,
#     Oppervlakte TEXT NOT NULL,
#     BrokerId INT REFERENCES BrokerAgencies(BrokerId),
#     Hyperlink TEXT NOT NULL,
#     Price TEXT NOT NULL,
#     Size TEXT NOT NULL
# );
#
# #### CRUD:
# Create:
# CreateNewBrokerAgency
# CreateNewRentalProperty
#
# Read:
# GetBrokerAgency
# GetPropertiesForBroker
# GetAllProperties
# GetAllPropertiesForLocation
#
# Update:
# UpdatePropertie
# UpdateBrokerAgency
#
# Delete:
# RemoveProperty
# RemoveBrokerAgency
#
#
#
# ### Webscraper (python):
#
# Moet kunnen ophalen:
# - Link naar appartement
# - Adress
# - Huurprijs
# - Oppervlakte
#
#
#
# ### Communicatielaag (python):
#
# communiceren tussen webscraper en db.
# uit locatie naam van dorp halen.
# logica voor aanmaken van items in de db.
# Controlleren op nieuwe appartementen.
# Opstellen mail met nieuwe appartementen en wat basis data.
#
#
#
# ### Mail service (python):
#
# Moet een mail kunnen versturen naar mijn of een andere mail.
#
#
#
# Moet kunnen draaien in een container die een of meerdere malen per dag kan worden afgevuurd (Liefst rond 12 uur smiddags en 6 uur savonds).
# kan blijkbaar via crontab op linux

# %% [markdown]
# ## Imports:

# %%
import psycopg2
from psycopg2 import sql
from datetime import date
from dataclasses import dataclass
from typing import List, Optional
import requests
from bs4 import BeautifulSoup
from abc import ABC, abstractmethod
import re
from urllib.parse import urljoin
from typing import Dict, List, Optional, Union, Any
import logging
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from queue import Queue
import logging
from datetime import datetime

# Import configuration
from config import DATABASE, EMAIL

# Import mail service
from mail_service import MailService

# Import data access
from data_access import DataAccess, BrokerAgency, Property

# Import logging service
from log_service import LogService, get_logger

# %% [markdown]
# ## Main:

# %%
# Importeer de connector
from connector import Connector


# Uitbreiden van connector met factory functies voor onze datamodellen
class Huurhuisconnector(Connector):
    def _create_broker_agency(self, id, naam, link):
        """Factory functie die een BrokerAgency object aanmaakt met de klasse uit data_access.py."""
        return BrokerAgency(id=id, naam=naam, link=link)

    def _create_property(
        self,
        makelaardij_id,
        adres,
        link,
        toegevoegd_op,
        naam_dorp_stad,
        huurprijs,
        oppervlakte,
    ):
        """Factory functie die een Property object aanmaakt met de klasse uit data_access.py."""
        return Property(
            makelaardij_id=makelaardij_id,
            adres=adres,
            link=link,
            toegevoegd_op=toegevoegd_op,
            naam_dorp_stad=naam_dorp_stad,
            huurprijs=huurprijs,
            oppervlakte=oppervlakte,
        )


def run_scraper_proces():
    """Voer het volledige scraper proces uit."""
    # Initialize logging service
    log_service = LogService()
    logger = get_logger("HuurhuisWebscraper")

    # Log application start
    log_service.log_app_start()

    # Initialiseer de database-verbinding
    db = DataAccess()

    # Initialiseer de connector met onze aangepaste versie
    communicatie = Huurhuisconnector(db)

    # Lijst met te verwerken makelaars en hun scraper-type
    makelaars = [
        {
            "naam": "Van Roomen Van de Bunt NVM Makelaars",
            "type": "vdbunt",
            "url": "https://www.vdbunt.nl/aanbod/woningaanbod/huur/",
        },
        {
            "naam": "Pararius",
            "type": "pararius",
            "url": "https://www.pararius.nl/huurwoningen/leusden/",
        },
        {
            "naam": "Zonnenberg Makelaardij",
            "type": "zonnenberg",
            "url": "https://zonnenbergmakelaardij.nl/woningaanbod/huur/",
        },
        {
            "naam": "Ditters Makelaars",
            "type": "ditters",
            "url": "https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur",
        },
        {
            "naam": "InterHouse Utrecht",
            "type": "interhouse-utrecht",
            "url": "https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list",
        },
        {
            "naam": "InterHouse Amersfoort",
            "type": "interhouse-amersfoort",
            "url": "https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list",
        },
        {
            "naam": "VastgoedNederland Veenendaal",
            "type": "vastgoednederland",
            "url": "https://aanbod.vastgoednederland.nl/huurwoningen?q=veenendaal&straal=15000",
        },
    ]

    # Set main thread name for better logging
    threading.current_thread().name = "MainThread"
    logger.info("Starting multithreaded scraper process")

    # Process brokers in parallel and gather results
    # Use max_workers based on number of brokers - for 4 brokers, use 4 threads
    max_workers = len(makelaars)
    logger.info(
        f"Processing {len(makelaars)} brokers with {max_workers} worker threads"
    )

    alle_nieuwe_properties, alle_verwijderde_properties = (
        communicatie.parallel_process_brokers(makelaars, max_workers=max_workers)
    )

    # After all scrapers have completed, synchronously apply database updates
    logger.info("All scrapers finished. Applying database updates synchronously...")
    communicatie.apply_database_updates(
        alle_nieuwe_properties, alle_verwijderde_properties
    )

    # Toon resultaten
    logger.info(f"Total new properties: {len(alle_nieuwe_properties)}")
    logger.info(f"Total removed properties: {len(alle_verwijderde_properties)}")

    # Verstuur mail met nieuwe woningen
    if alle_nieuwe_properties:
        logger.info(f"Sending email with {len(alle_nieuwe_properties)} new properties")

        # Initialiseer de mail service met de configuratie uit config.py
        mail_service = MailService()

        # Verstuur de mail met nieuwe woningen
        mail_success = mail_service.send_new_properties_email(
            None, alle_nieuwe_properties
        )

        if mail_success:
            logger.info(
                f"E-mail with {len(alle_nieuwe_properties)} new properties successfully sent to {len(EMAIL['recipients'])} recipient(s)"
            )
        else:
            logger.error("There was a problem sending the email.")

    # Log application end
    log_service.log_app_end(
        len(alle_nieuwe_properties), len(alle_verwijderde_properties)
    )


run_scraper_proces()
# Out:
# 2025-05-13 18:10:12,851 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Started =====
# 2025-05-13 18:10:12,852 - [MainThread] - root - INFO - Start time: 2025-05-13 18:10:12
# 2025-05-13 18:10:12,853 - [MainThread] - HuurhuisWebscraper - INFO - Starting multithreaded scraper process
# 2025-05-13 18:10:12,853 - [MainThread] - HuurhuisWebscraper - INFO - Processing 7 brokers with 7 worker threads
# 2025-05-13 18:10:12,854 - [MainThread] - connector - INFO - Starting parallel processing of 7 brokers with max_workers=7
# 2025-05-13 18:10:12,852 - [MainThread] - root - INFO - Start time: 2025-05-13 18:10:12
# 2025-05-13 18:10:12,853 - [MainThread] - HuurhuisWebscraper - INFO - Starting multithreaded scraper process
# 2025-05-13 18:10:12,853 - [MainThread] - HuurhuisWebscraper - INFO - Processing 7 brokers with 7 worker threads
# 2025-05-13 18:10:12,854 - [MainThread] - connector - INFO - Starting parallel processing of 7 brokers with max_workers=7
# 2025-05-13 18:10:12,856 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Verwerken van makelaar: Van Roomen Van de Bunt NVM Makelaars op thread Thread-Van Roomen Van de Bunt NVM Makelaars
# 2025-05-13 18:10:12,869 - [Thread-Pararius] - connector - INFO - Verwerken van makelaar: Pararius op thread Thread-Pararius
# 2025-05-13 18:10:12,856 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Verwerken van makelaar: Van Roomen Van de Bunt NVM Makelaars op thread Thread-Van Roomen Van de Bunt NVM Makelaars
# 2025-05-13 18:10:12,869 - [Thread-Pararius] - connector - INFO - Verwerken van makelaar: Pararius op thread Thread-Pararius
# 2025-05-13 18:10:12,871 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Verwerken van makelaar: Zonnenberg Makelaardij op thread Thread-Zonnenberg Makelaardij
# 2025-05-13 18:10:12,871 - [Thread-Ditters Makelaars] - connector - INFO - Verwerken van makelaar: Ditters Makelaars op thread Thread-Ditters Makelaars
# 2025-05-13 18:10:12,873 - [Thread-InterHouse Utrecht] - connector - INFO - Verwerken van makelaar: InterHouse Utrecht op thread Thread-InterHouse Utrecht
# 2025-05-13 18:10:12,871 - [Thread-Ditters Makelaars] - connector - INFO - Verwerken van makelaar: Ditters Makelaars op thread Thread-Ditters Makelaars
# 2025-05-13 18:10:12,873 - [Thread-InterHouse Utrecht] - connector - INFO - Verwerken van makelaar: InterHouse Utrecht op thread Thread-InterHouse Utrecht
# 2025-05-13 18:10:12,873 - [Thread-InterHouse Amersfoort] - connector - INFO - Verwerken van makelaar: InterHouse Amersfoort op thread Thread-InterHouse Amersfoort
# 2025-05-13 18:10:12,876 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Verwerken van makelaar: VastgoedNederland Veenendaal op thread Thread-VastgoedNederland Veenendaal
# 2025-05-13 18:10:12,873 - [Thread-InterHouse Amersfoort] - connector - INFO - Verwerken van makelaar: InterHouse Amersfoort op thread Thread-InterHouse Amersfoort
# 2025-05-13 18:10:12,876 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Verwerken van makelaar: VastgoedNederland Veenendaal op thread Thread-VastgoedNederland Veenendaal
# 2025-05-13 18:10:13,051 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,052 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 18:10:13,053 - [Thread-InterHouse Utrecht] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 18:10:13,051 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,052 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 18:10:13,053 - [Thread-InterHouse Utrecht] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 18:10:13,090 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Makelaar VastgoedNederland Veenendaal bestaat nog niet, wordt aangemaakt
# 2025-05-13 18:10:13,093 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,093 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/
# 2025-05-13 18:10:13,095 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,096 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,096 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - VdBunt scraper only processes first page since pagination is not supported
# 2025-05-13 18:10:13,102 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,100 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur
# 2025-05-13 18:10:13,100 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 18:10:13,090 - [Thread-VastgoedNederland Veenendaal] - connector - INFO - Makelaar VastgoedNederland Veenendaal bestaat nog niet, wordt aangemaakt
# 2025-05-13 18:10:13,093 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,093 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/
# 2025-05-13 18:10:13,095 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,096 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,096 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - VdBunt scraper only processes first page since pagination is not supported
# 2025-05-13 18:10:13,102 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,100 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur
# 2025-05-13 18:10:13,100 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list
# 2025-05-13 18:10:13,100 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,102 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Retrieving page: https://www.vdbunt.nl/aanbod/woningaanbod/huur/
# 2025-05-13 18:10:13,105 - [Thread-InterHouse Amersfoort] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 18:10:13,100 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 1
# 2025-05-13 18:10:13,102 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Retrieving page: https://www.vdbunt.nl/aanbod/woningaanbod/huur/
# 2025-05-13 18:10:13,105 - [Thread-InterHouse Amersfoort] - WDM - INFO - ====== WebDriver manager ======
# 2025-05-13 18:10:13,203 - [Thread-VastgoedNederland Veenendaal] - connector - ERROR - Fout bij ophalen scraper: No scraper available for website: vastgoednederland. Available scrapers: vdbunt, pararius, zonnenberg, ditters, interhouse, interhouse-utrecht, interhouse-amersfoort
# 2025-05-13 18:10:13,203 - [Thread-VastgoedNederland Veenendaal] - connector - ERROR - Fout bij ophalen scraper: No scraper available for website: vastgoednederland. Available scrapers: vdbunt, pararius, zonnenberg, ditters, interhouse, interhouse-utrecht, interhouse-amersfoort
# 2025-05-13 18:10:13,217 - [MainThread] - connector - ERROR - Broker VastgoedNederland Veenendaal generated an exception: No scraper available for website: vastgoednederland. Available scrapers: vdbunt, pararius, zonnenberg, ditters, interhouse, interhouse-utrecht, interhouse-amersfoort
# 2025-05-13 18:10:13,217 - [MainThread] - connector - ERROR - Broker VastgoedNederland Veenendaal generated an exception: No scraper available for website: vastgoednederland. Available scrapers: vdbunt, pararius, zonnenberg, ditters, interhouse, interhouse-utrecht, interhouse-amersfoort
# 2025-05-13 18:10:13,295 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 2 properties on Ditters website (page 1)
# 2025-05-13 18:10:13,301 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:13,305 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 2
# 2025-05-13 18:10:13,295 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 2 properties on Ditters website (page 1)
# 2025-05-13 18:10:13,301 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:13,305 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Processing page 2
# 2025-05-13 18:10:13,307 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur&page=2
# 2025-05-13 18:10:13,307 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Retrieving page: https://www.ditters.nl/woningaanbod/?filter%5Bcategory%5D=%2FHuur&page=2
# 2025-05-13 18:10:13,475 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 0 properties on Ditters website (page 2)
# 2025-05-13 18:10:13,476 - [Thread-Ditters Makelaars] - DittersScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:13,476 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:13,477 - [Thread-Ditters Makelaars] - connector - INFO - Makelaar: Ditters Makelaars| Gevonden properties: 2
# 2025-05-13 18:10:13,475 - [Thread-Ditters Makelaars] - WebScraper - INFO - Found 0 properties on Ditters website (page 2)
# 2025-05-13 18:10:13,476 - [Thread-Ditters Makelaars] - DittersScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:13,476 - [Thread-Ditters Makelaars] - DittersScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:13,477 - [Thread-Ditters Makelaars] - connector - INFO - Makelaar: Ditters Makelaars| Gevonden properties: 2
# 2025-05-13 18:10:13,582 - [Thread-Ditters Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:13,582 - [Thread-Ditters Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:13,585 - [Thread-Ditters Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:13,606 - [Thread-Ditters Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:13,608 - [Thread-Ditters Makelaars] - root - INFO - Broker: Ditters Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:13,585 - [Thread-Ditters Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:13,606 - [Thread-Ditters Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:13,608 - [Thread-Ditters Makelaars] - root - INFO - Broker: Ditters Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:13,723 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - Found 2 properties on VdBunt website
# 2025-05-13 18:10:13,723 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - WebScraper - INFO - Found 2 properties on VdBunt website
# 2025-05-13 18:10:13,749 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:13,749 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:13,767 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:13,767 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - VdBuntScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:13,805 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Makelaar: Van Roomen Van de Bunt NVM Makelaars| Gevonden properties: 2
# 2025-05-13 18:10:13,811 - [Thread-Pararius] - ParariusScraper - INFO - Page: 1 | Found new: 30 | Duplicates: 0
# 2025-05-13 18:10:13,815 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 2
# 2025-05-13 18:10:13,816 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/page-2
# 2025-05-13 18:10:13,805 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Makelaar: Van Roomen Van de Bunt NVM Makelaars| Gevonden properties: 2
# 2025-05-13 18:10:13,811 - [Thread-Pararius] - ParariusScraper - INFO - Page: 1 | Found new: 30 | Duplicates: 0
# 2025-05-13 18:10:13,815 - [Thread-Pararius] - ParariusScraper - INFO - Processing page 2
# 2025-05-13 18:10:13,816 - [Thread-Pararius] - ParariusScraper - INFO - Retrieving page: https://www.pararius.nl/huurwoningen/leusden/page-2
# 2025-05-13 18:10:13,885 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:13,886 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:13,887 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:13,887 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - root - INFO - Broker: Van Roomen Van de Bunt NVM Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:13,885 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:13,886 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:13,887 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:13,887 - [Thread-Van Roomen Van de Bunt NVM Makelaars] - root - INFO - Broker: Van Roomen Van de Bunt NVM Makelaars | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:14,187 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:14,189 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 2
# 2025-05-13 18:10:14,187 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Page: 1 | Found new: 2 | Duplicates: 0
# 2025-05-13 18:10:14,189 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Processing page 2
# 2025-05-13 18:10:14,543 - [Thread-Pararius] - ParariusScraper - INFO - All 30 listings on page 2 are duplicates. Stopping pagination.
# 2025-05-13 18:10:14,544 - [Thread-Pararius] - ParariusScraper - INFO - Total properties found: 30
# 2025-05-13 18:10:14,546 - [Thread-Pararius] - connector - INFO - Makelaar: Pararius| Gevonden properties: 30
# 2025-05-13 18:10:14,543 - [Thread-Pararius] - ParariusScraper - INFO - All 30 listings on page 2 are duplicates. Stopping pagination.
# 2025-05-13 18:10:14,544 - [Thread-Pararius] - ParariusScraper - INFO - Total properties found: 30
# 2025-05-13 18:10:14,546 - [Thread-Pararius] - connector - INFO - Makelaar: Pararius| Gevonden properties: 30
# 2025-05-13 18:10:14,696 - [Thread-Pararius] - connector - INFO - Nieuwe properties: 1
# 2025-05-13 18:10:14,697 - [Thread-Pararius] - connector - INFO - Bestaande properties: 29
# 2025-05-13 18:10:14,698 - [Thread-Pararius] - connector - INFO - Te verwijderen properties: 1
# 2025-05-13 18:10:14,699 - [Thread-Pararius] - root - INFO - Broker: Pararius | New properties: 1 | Removed properties: 1
# 2025-05-13 18:10:14,696 - [Thread-Pararius] - connector - INFO - Nieuwe properties: 1
# 2025-05-13 18:10:14,697 - [Thread-Pararius] - connector - INFO - Bestaande properties: 29
# 2025-05-13 18:10:14,698 - [Thread-Pararius] - connector - INFO - Te verwijderen properties: 1
# 2025-05-13 18:10:14,699 - [Thread-Pararius] - root - INFO - Broker: Pararius | New properties: 1 | Removed properties: 1
# 2025-05-13 18:10:15,147 - [Thread-Zonnenberg Makelaardij] - WebScraper - ERROR - Failed to get content from https://zonnenbergmakelaardij.nl/woningaanbod/huur/page/2/, status code: 404
# 2025-05-13 18:10:15,148 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:15,149 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,149 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:15,153 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Makelaar: Zonnenberg Makelaardij| Gevonden properties: 2
# 2025-05-13 18:10:15,147 - [Thread-Zonnenberg Makelaardij] - WebScraper - ERROR - Failed to get content from https://zonnenbergmakelaardij.nl/woningaanbod/huur/page/2/, status code: 404
# 2025-05-13 18:10:15,148 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:15,149 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,149 - [Thread-Zonnenberg Makelaardij] - ZonnenbergScraper - INFO - Total properties found: 2
# 2025-05-13 18:10:15,153 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Makelaar: Zonnenberg Makelaardij| Gevonden properties: 2
# 2025-05-13 18:10:15,191 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,197 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,191 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,197 - [Thread-InterHouse Utrecht] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,226 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,233 - [Thread-InterHouse Utrecht] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 18:10:15,226 - [Thread-InterHouse Amersfoort] - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2025-05-13 18:10:15,233 - [Thread-InterHouse Utrecht] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 18:10:15,439 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:15,440 - [Thread-InterHouse Amersfoort] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 18:10:15,444 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:15,447 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:15,448 - [Thread-Zonnenberg Makelaardij] - root - INFO - Broker: Zonnenberg Makelaardij | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:15,439 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:15,440 - [Thread-InterHouse Amersfoort] - WDM - INFO - Driver [C:\Users\User\.wdm\drivers\chromedriver\win64\136.0.7103.92\chromedriver-win32/chromedriver.exe] found in cache
# 2025-05-13 18:10:15,444 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Bestaande properties: 2
# 2025-05-13 18:10:15,447 - [Thread-Zonnenberg Makelaardij] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:15,448 - [Thread-Zonnenberg Makelaardij] - root - INFO - Broker: Zonnenberg Makelaardij | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:16,070 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 18:10:16,070 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 18:10:16,535 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 18:10:16,535 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Selenium WebDriver initialized successfully
# 2025-05-13 18:10:17,337 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 9 properties on InterHouse website for Utrecht (page 1)
# 2025-05-13 18:10:17,349 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Page: 1 | Found new: 9 | Duplicates: 0
# 2025-05-13 18:10:17,351 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 18:10:17,337 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 9 properties on InterHouse website for Utrecht (page 1)
# 2025-05-13 18:10:17,349 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Page: 1 | Found new: 9 | Duplicates: 0
# 2025-05-13 18:10:17,351 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 18:10:17,351 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 18:10:17,351 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Utrecht_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 18:10:17,977 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 7 properties on InterHouse website for Amersfoort (page 1)
# 2025-05-13 18:10:17,986 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 18:10:17,977 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 7 properties on InterHouse website for Amersfoort (page 1)
# 2025-05-13 18:10:17,986 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Page: 1 | Found new: 7 | Duplicates: 0
# 2025-05-13 18:10:17,988 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 18:10:17,988 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 18:10:17,988 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Processing page 2
# 2025-05-13 18:10:17,988 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Retrieving page with Selenium: https://interhouse.nl/huurwoningen/?location_id=Amersfoort_Algemeen&number_of_results=20&sort=date-desc&display=list&paging=2
# 2025-05-13 18:10:27,849 - [Thread-InterHouse Utrecht] - InterHouseScraper - WARNING - Timeout waiting for page elements: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00F3FC53+61635]
# 	GetHandleVerifier [0x00F3FC94+61700]
# 	(No symbol) [0x00D605D3]
# 	(No symbol) [0x00DA899E]
# 	(No symbol) [0x00DA8D3B]
# 	(No symbol) [0x00DF0E12]
# 	(No symbol) [0x00DCD2E4]
# 	(No symbol) [0x00DEE61B]
# 	(No symbol) [0x00DCD096]
# 	(No symbol) [0x00D9C840]
# 	(No symbol) [0x00D9D6A4]
# 	GetHandleVerifier [0x011C4573+2701795]
# 	GetHandleVerifier [0x011BFCF6+2683238]
# 	GetHandleVerifier [0x011DAA3E+2793134]
# 	GetHandleVerifier [0x00F56915+155013]
# 	GetHandleVerifier [0x00F5CFFD+181357]
# 	GetHandleVerifier [0x00F474A8+92440]
# 	GetHandleVerifier [0x00F47650+92864]
# 	GetHandleVerifier [0x00F32040+5296]
# 	BaseThreadInitThunk [0x76435D49+25]
# 	RtlInitializeExceptionChain [0x77E9CFFB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77E9CF81+561]
#
# 2025-05-13 18:10:27,849 - [Thread-InterHouse Utrecht] - InterHouseScraper - WARNING - Timeout waiting for page elements: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00F3FC53+61635]
# 	GetHandleVerifier [0x00F3FC94+61700]
# 	(No symbol) [0x00D605D3]
# 	(No symbol) [0x00DA899E]
# 	(No symbol) [0x00DA8D3B]
# 	(No symbol) [0x00DF0E12]
# 	(No symbol) [0x00DCD2E4]
# 	(No symbol) [0x00DEE61B]
# 	(No symbol) [0x00DCD096]
# 	(No symbol) [0x00D9C840]
# 	(No symbol) [0x00D9D6A4]
# 	GetHandleVerifier [0x011C4573+2701795]
# 	GetHandleVerifier [0x011BFCF6+2683238]
# 	GetHandleVerifier [0x011DAA3E+2793134]
# 	GetHandleVerifier [0x00F56915+155013]
# 	GetHandleVerifier [0x00F5CFFD+181357]
# 	GetHandleVerifier [0x00F474A8+92440]
# 	GetHandleVerifier [0x00F47650+92864]
# 	GetHandleVerifier [0x00F32040+5296]
# 	BaseThreadInitThunk [0x76435D49+25]
# 	RtlInitializeExceptionChain [0x77E9CFFB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77E9CF81+561]
#
# 2025-05-13 18:10:27,956 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Utrecht (page 2)
# 2025-05-13 18:10:27,958 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:27,959 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Total properties found: 9
# 2025-05-13 18:10:27,956 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Utrecht (page 2)
# 2025-05-13 18:10:27,958 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:27,959 - [Thread-InterHouse Utrecht] - InterHouseScraper - INFO - Total properties found: 9
# 2025-05-13 18:10:28,548 - [Thread-InterHouse Amersfoort] - InterHouseScraper - WARNING - Timeout waiting for page elements: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00F3FC53+61635]
# 	GetHandleVerifier [0x00F3FC94+61700]
# 	(No symbol) [0x00D605D3]
# 	(No symbol) [0x00DA899E]
# 	(No symbol) [0x00DA8D3B]
# 	(No symbol) [0x00DF0E12]
# 	(No symbol) [0x00DCD2E4]
# 	(No symbol) [0x00DEE61B]
# 	(No symbol) [0x00DCD096]
# 	(No symbol) [0x00D9C840]
# 	(No symbol) [0x00D9D6A4]
# 	GetHandleVerifier [0x011C4573+2701795]
# 	GetHandleVerifier [0x011BFCF6+2683238]
# 	GetHandleVerifier [0x011DAA3E+2793134]
# 	GetHandleVerifier [0x00F56915+155013]
# 	GetHandleVerifier [0x00F5CFFD+181357]
# 	GetHandleVerifier [0x00F474A8+92440]
# 	GetHandleVerifier [0x00F47650+92864]
# 	GetHandleVerifier [0x00F32040+5296]
# 	BaseThreadInitThunk [0x76435D49+25]
# 	RtlInitializeExceptionChain [0x77E9CFFB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77E9CF81+561]
#
# 2025-05-13 18:10:28,548 - [Thread-InterHouse Amersfoort] - InterHouseScraper - WARNING - Timeout waiting for page elements: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00F3FC53+61635]
# 	GetHandleVerifier [0x00F3FC94+61700]
# 	(No symbol) [0x00D605D3]
# 	(No symbol) [0x00DA899E]
# 	(No symbol) [0x00DA8D3B]
# 	(No symbol) [0x00DF0E12]
# 	(No symbol) [0x00DCD2E4]
# 	(No symbol) [0x00DEE61B]
# 	(No symbol) [0x00DCD096]
# 	(No symbol) [0x00D9C840]
# 	(No symbol) [0x00D9D6A4]
# 	GetHandleVerifier [0x011C4573+2701795]
# 	GetHandleVerifier [0x011BFCF6+2683238]
# 	GetHandleVerifier [0x011DAA3E+2793134]
# 	GetHandleVerifier [0x00F56915+155013]
# 	GetHandleVerifier [0x00F5CFFD+181357]
# 	GetHandleVerifier [0x00F474A8+92440]
# 	GetHandleVerifier [0x00F47650+92864]
# 	GetHandleVerifier [0x00F32040+5296]
# 	BaseThreadInitThunk [0x76435D49+25]
# 	RtlInitializeExceptionChain [0x77E9CFFB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77E9CF81+561]
#
# 2025-05-13 18:10:28,667 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Amersfoort (page 2)
# 2025-05-13 18:10:28,668 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:28,669 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Total properties found: 7
# 2025-05-13 18:10:28,667 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Found 0 properties on InterHouse website for Amersfoort (page 2)
# 2025-05-13 18:10:28,668 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - No more results found on page 2. Stopping.
# 2025-05-13 18:10:28,669 - [Thread-InterHouse Amersfoort] - InterHouseScraper - INFO - Total properties found: 7
# 2025-05-13 18:10:30,082 - [Thread-InterHouse Utrecht] - connector - INFO - Makelaar: InterHouse Utrecht| Gevonden properties: 9
# 2025-05-13 18:10:30,082 - [Thread-InterHouse Utrecht] - connector - INFO - Makelaar: InterHouse Utrecht| Gevonden properties: 9
# 2025-05-13 18:10:30,139 - [Thread-InterHouse Utrecht] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:30,140 - [Thread-InterHouse Utrecht] - connector - INFO - Bestaande properties: 9
# 2025-05-13 18:10:30,141 - [Thread-InterHouse Utrecht] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:30,141 - [Thread-InterHouse Utrecht] - root - INFO - Broker: InterHouse Utrecht | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:30,139 - [Thread-InterHouse Utrecht] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:30,140 - [Thread-InterHouse Utrecht] - connector - INFO - Bestaande properties: 9
# 2025-05-13 18:10:30,141 - [Thread-InterHouse Utrecht] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:30,141 - [Thread-InterHouse Utrecht] - root - INFO - Broker: InterHouse Utrecht | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:30,806 - [Thread-InterHouse Amersfoort] - connector - INFO - Makelaar: InterHouse Amersfoort| Gevonden properties: 7
# 2025-05-13 18:10:30,806 - [Thread-InterHouse Amersfoort] - connector - INFO - Makelaar: InterHouse Amersfoort| Gevonden properties: 7
# 2025-05-13 18:10:30,862 - [Thread-InterHouse Amersfoort] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:30,863 - [Thread-InterHouse Amersfoort] - connector - INFO - Bestaande properties: 7
# 2025-05-13 18:10:30,864 - [Thread-InterHouse Amersfoort] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:30,865 - [Thread-InterHouse Amersfoort] - root - INFO - Broker: InterHouse Amersfoort | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:30,866 - [MainThread] - connector - INFO - Parallel processing completed - Found 1 new and 1 removed properties
# 2025-05-13 18:10:30,867 - [MainThread] - HuurhuisWebscraper - INFO - All scrapers finished. Applying database updates synchronously...
# 2025-05-13 18:10:30,867 - [MainThread] - connector - INFO - Applying database updates - 1 new, 1 removed
# 2025-05-13 18:10:30,862 - [Thread-InterHouse Amersfoort] - connector - INFO - Nieuwe properties: 0
# 2025-05-13 18:10:30,863 - [Thread-InterHouse Amersfoort] - connector - INFO - Bestaande properties: 7
# 2025-05-13 18:10:30,864 - [Thread-InterHouse Amersfoort] - connector - INFO - Te verwijderen properties: 0
# 2025-05-13 18:10:30,865 - [Thread-InterHouse Amersfoort] - root - INFO - Broker: InterHouse Amersfoort | New properties: 0 | Removed properties: 0
# 2025-05-13 18:10:30,866 - [MainThread] - connector - INFO - Parallel processing completed - Found 1 new and 1 removed properties
# 2025-05-13 18:10:30,867 - [MainThread] - HuurhuisWebscraper - INFO - All scrapers finished. Applying database updates synchronously...
# 2025-05-13 18:10:30,867 - [MainThread] - connector - INFO - Applying database updates - 1 new, 1 removed
# 2025-05-13 18:10:31,125 - [MainThread] - HuurhuisWebscraper - INFO - Total new properties: 1
# 2025-05-13 18:10:31,126 - [MainThread] - HuurhuisWebscraper - INFO - Total removed properties: 1
# 2025-05-13 18:10:31,127 - [MainThread] - HuurhuisWebscraper - INFO - Sending email with 1 new properties
# 2025-05-13 18:10:31,125 - [MainThread] - HuurhuisWebscraper - INFO - Total new properties: 1
# 2025-05-13 18:10:31,126 - [MainThread] - HuurhuisWebscraper - INFO - Total removed properties: 1
# 2025-05-13 18:10:31,127 - [MainThread] - HuurhuisWebscraper - INFO - Sending email with 1 new properties
# 2025-05-13 18:10:33,470 - [MainThread] - MailService - INFO - E-mail succesvol verzonden naar 1 ontvanger(s).
# 2025-05-13 18:10:33,471 - [MainThread] - HuurhuisWebscraper - INFO - E-mail with 1 new properties successfully sent to 1 recipient(s)
# 2025-05-13 18:10:33,471 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Completed =====
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - End time: 2025-05-13 18:10:33
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - New properties found: 1
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - Properties removed: 1
# 2025-05-13 18:10:33,470 - [MainThread] - MailService - INFO - E-mail succesvol verzonden naar 1 ontvanger(s).
# 2025-05-13 18:10:33,471 - [MainThread] - HuurhuisWebscraper - INFO - E-mail with 1 new properties successfully sent to 1 recipient(s)
# 2025-05-13 18:10:33,471 - [MainThread] - root - INFO - ===== HuurhuisWebscraper Completed =====
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - End time: 2025-05-13 18:10:33
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - New properties found: 1
# 2025-05-13 18:10:33,472 - [MainThread] - root - INFO - Properties removed: 1
